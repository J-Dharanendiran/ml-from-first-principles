# %% [markdown]
# # Understand what the dataset contains

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("C:\Dharan\Cheat Sheets\Datasets\Data_Train.xlsx")

# %% [markdown]
# ### How big is the data?

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10683, step=1)

# %% [markdown]
# ### How does the data looks like?

# %%
df.head(8)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 5     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
# 6  Jet Airways      12/03/2019  Banglore   New Delhi        BLR → BOM → DEL
# 7  Jet Airways      01/03/2019  Banglore   New Delhi        BLR → BOM → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop                      No info
# 1    05:50         13:15   7h 25m     2 stops                      No info
# ...

# %%
df.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
df.sample(10)
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 296         Jet Airways      21/03/2019  Banglore   New Delhi
# 2435        Jet Airways       9/06/2019   Kolkata    Banglore
# 4390        Jet Airways      18/03/2019  Banglore   New Delhi
# 7140             IndiGo      21/05/2019  Banglore       Delhi
# 9341        Jet Airways       9/05/2019    Mumbai   Hyderabad
# 3444          Air India      12/05/2019   Kolkata    Banglore
# 3761        Jet Airways       9/05/2019   Kolkata    Banglore
# 832   Multiple carriers       9/05/2019     Delhi      Cochin
# 8040          Air India      15/03/2019  Banglore   New Delhi
# 3424  Multiple carriers       9/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 296         BLR → BOM → DEL    07:00         19:10  12h 10m      1 stop
# 2435        CCU → BOM → BLR    06:30         19:50  13h 20m      1 stop
# ...

# %% [markdown]
# ### What are the datatypes of the columns?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# ### Are there any missing values?

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# ### Percentage of missing values in the dataset

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Airline            0.000000
# Date_of_Journey    0.000000
# Source             0.000000
# Destination        0.000000
# Route              0.009361
# Dep_Time           0.000000
# Arrival_Time       0.000000
# Duration           0.000000
# Total_Stops        0.009361
# Additional_Info    0.000000
# Price              0.000000
# dtype: float64

# %% [markdown]
# ### How does the data look mathematically?

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.describe(include='object')
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count         10683           10683  10683       10683            10682
# unique           12              44      5           6              128
# top     Jet Airways      18/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq           3849             504   4537        4537             2376
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count     10683        10683    10683       10682           10683
# unique      222         1343      368           5              10
# top       18:55        19:00   2h 50m      1 stop         No info
# freq        233          423      550        5625            8345

# %% [markdown]
# 🚨 Important observations from this table
#
# From this single summary, you've already learned:
#
# ✅ Dataset has 10,683 rows.
#
# ✅ There are 12 airlines.
#
# ✅ Flights originate from 5 source cities.
#
# ✅ Flights arrive at 6 destination cities.
#
# ✅ There are 128 unique routes.
#
# ✅ Route has 1 missing value.
#
# ✅ Total_Stops has 1 missing value.
#
# ✅ Most flights are operated by Jet Airways.
#
# ✅ Most flights are from Delhi to Cochin.
#
# ✅ Most flights have 1 stop.
#
# ✅ Additional_Info is mostly "No info", making it a candidate for closer inspection during feature engineering.

# %% [markdown]
# ### Checking for duplicated values if any

# %%
df.duplicated().sum()
# Out:
# np.int64(220)

# %%
df[df.duplicated()]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 683    Jet Airways       1/06/2019     Delhi      Cochin
# 1061     Air India      21/05/2019     Delhi      Cochin
# 1348     Air India      18/05/2019     Delhi      Cochin
# 1418   Jet Airways       6/06/2019     Delhi      Cochin
# 1674        IndiGo      24/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683    DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061   DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# ...

# %%
df.nunique()
# Out:
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# #### df['column name'].value_counts tells us the no of unique values in a column and no of times it is appearing...

# %%
df['Airline'].value_counts()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df['Source'].value_counts()
# Out:
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
df['Route'].value_counts()
# Out:
# Route
# DEL → BOM → COK                      2376
# BLR → DEL                            1552
# CCU → BOM → BLR                       979
# CCU → BLR                             724
# BOM → HYD                             621
#                                      ...
# BOM → VNS → DEL → HYD                   1
# BLR → HBX → BOM → NAG → DEL             1
# BLR → BOM → IXC → DEL                   1
# BLR → CCU → BBI → HYD → VGA → DEL       1
# BOM → BBI → HYD                         1
# Name: count, Length: 128, dtype: int64

# %%
df['Duration'].value_counts()
# Out:
# Duration
# 2h 50m     550
# 1h 30m     386
# 2h 55m     337
# 2h 45m     337
# 2h 35m     329
#           ...
# 30h 10m      1
# 31h 30m      1
# 42h 5m       1
# 4h 10m       1
# 5m           1
# Name: count, Length: 368, dtype: int64

# %%
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
df["Price"].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64
